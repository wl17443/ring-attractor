# %%
include("ring_attractor.jl");
include("stats.jl");
include("search_stable_weights.jl")
# Out:
# check_idx (generic function with 2 methods)

# %%
stable_mean, stable_var = fit_errors(1000, (24, 40), par)
unstable_mean, unstable_var = fit_errors(1000, (), par)
# Out:
# (Gamma{Float64}(α=3.165794979106515, θ=0.09668193141576624), Gamma{Float64}(α=0.9392840165348452, θ=0.14499252798786721))

# %%
se, si, ue, ui = find_stability_range(par, 3, 0.01, 0.50, 0.01, 0.50);

# %%
plot_stability_range(si,se,ui,ue)
