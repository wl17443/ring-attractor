# %% [markdown]
# This notebook is meant to help recording and organizing the work toward a clean bias-variance curve
#
# ### Workflow
#
# 1. Simulation
# 2. Analyis
# 3. Observations
# 4. Debugging
# 5. Fixes and Parameter Tuning
# 6. Repeat

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ring_attractor import RingAttractor

# %% [markdown]
# # Batch 1
#
# ### 1. Simulation
#
# >   "neurons_n": 256,
#     "simulation_time": 10000,
#     "iterations": 1,
#     "noise_levels": 300,
#     "noise_low": 0.0,
#     "noise_high": 1.5e-3,
#     "weights": [0.050, 0.100, 0.050, 0.250],
#     "fixed_points": [0, 1, 2, 4, 8, 16, 32]

# %%
df = pd.read_csv('backups/batch_1/300_noise_levels.csv', index_col=0)
df
# Out:
#     0.00e+00  5.02e-06  1.00e-05  1.51e-05  2.01e-05  2.51e-05  3.01e-05  \
# 0   5.964097  5.964097  5.964097  5.964097  5.964097  5.964097  5.964097
# 1   5.964097  5.964097  5.964097  5.964097  5.964097  5.964097  5.964097
# 2   0.790898  0.790898  0.790898  0.790898  0.790898  0.790898  0.790898
# 4   0.790898  0.790898  0.790898  0.790898  0.790898  0.790898  0.790898
# 8   0.790898  0.790898  0.790898  0.790898  0.790898  0.790898  0.790898
# 16  0.790898  0.790898  0.790898  0.790898  0.790898  0.790898  0.790898
# 32  6.328125  6.328125  6.328125  6.328125  6.328125  6.328125  6.328125
#
#     3.51e-05  4.01e-05  4.52e-05  ...  1.45e-03.1   1.46e-03  1.46e-03.1  \
# 0   5.964097  5.964097  5.964097  ...   55.410308  47.472019   47.472019
# 1   5.964097  5.964097  5.964097  ...   55.410308  47.472019   47.472019
# 2   0.790898  0.790898  0.790898  ...   36.547165  55.672774   55.672774
# 4   0.790898  0.790898  0.790898  ...   45.298190  45.703340   45.703340
# ...

# %% [markdown]
# ### 2. Analysis

# %%
fig = plt.figure(figsize=(20,5))
df.idxmin().plot()

# %% [markdown]
# ### 3. Observations
#
#     a. randomness counts
#     b. after 8e-4 nothing interesting happens
#     c. still need to fix the starting point
#
# ### 4. Debugging
#
# Not needed for this
#
# ### 5. Fixes
#
#     a. We need to take the mean between more than 1 iteration
#     b. We need to focus on 0 - 0.8e-4
#     c. We need to fix the starting point
